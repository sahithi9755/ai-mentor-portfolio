# %% [markdown]
# <a href="https://colab.research.google.com/github/sahithi9755/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skills needed to build and manage AI solutions:
#
# *   **Data (Layer 1):** The foundational layer focusing on collecting, cleaning, storing, and managing the vast datasets essential for AI development.
# *   **AI Engineering & Model Development (Layers 2 & 3):** Building the infrastructure, deploying systems (MLOps), and designing, training, and evaluating the actual machine learning models.
# *   **AI Application & Domain Expertise (Layer 4):** Integrating trained AI models into specific business processes, understanding real-world problems, and ensuring AI delivers tangible value.
# *   **AI Strategy & Leadership (Layer 5):** The top layer focusing on defining the ethical guidelines, business value, governance, and long-term vision for AI initiatives within an organization.
